# %%
import pandas as pd

# Read the CSV file with semicolon as the delimiter
df = pd.read_csv("/Users/ulrike_imac_air/projects/DataScienceProjects/tech_layoffs/tech_layoffs_csv/layoffs_location_with_coordinates.csv", sep=';')

# Display the first few rows to verify that the file is read correctly
display(df.head())
display(df.info(verbose=True))
# Out:
#     location_HQ                  Region       State      Country  \
# 0      Adelaide                     NaN         NaN    Australia
# 1  Agoura Hills                     NaN  California          USA
# 2     Ahmedabad                     NaN         NaN        India
# 3       Alameda  San Francisco Bay Area  California          USA
# 4     Amsterdam                     NaN         NaN  Netherlands
#
#        Continent     latitude     longitude
# 0         Oceana  -34,9281805   138,5999312
# 1  North America   34,1479100  -118,7657042
# 2           Asia   23,0216238    72,5797068
# 3  North America   37,6090291  -121,8991420
# 4         Europe   52,3730796     4,8924534
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location_HQ  218 non-null    object
#  1   Region       35 non-null     object
#  2   State        116 non-null    object
#  3   Country      218 non-null    object
#  4   Continent    218 non-null    object
#  5   latitude     218 non-null    object
#  6   longitude    218 non-null    object
# dtypes: object(7)
# memory usage: 12.1+ KB
# None

# %% [markdown]
# I will use a Python geopy library to get the coordinates:

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from typing import Tuple
from functools import lru_cache
import time

geolocator = Nominatim(user_agent="Python3.12")

@lru_cache(maxsize=None)
def get_coord_lat_lon(location_HQ: str, Country: str = None) -> Tuple[float, float]:
    """ Get coordinates for Cities """
    if Country:
        location = geolocator.geocode(location_HQ + ', ' + Country)
    else:
        location = geolocator.geocode(location_HQ)
    return (location.latitude, location.longitude) if location else (None, None)

# Assuming 'df' is your DataFrame and it has 'location_HQ' and 'Country' columns
# Create empty lists to store latitude and longitude
latitudes = []
longitudes = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    location_HQ = row['location_HQ']
    Country = row.get('Country')  # Use get to avoid KeyError if 'Country' might be missing

    lat, lon = get_coord_lat_lon(location_HQ, Country)
    if lat is not None and lon is not None:
        latitudes.append(lat)
        longitudes.append(lon)
    else:
        latitudes.append(None)
        longitudes.append(None)
    
    # Respect Nominatim's usage policy and avoid making too many requests in a short period
    time.sleep(1)  # Sleep for 1 second

# Add latitude and longitude columns to the DataFrame
df['latitude'] = latitudes
df['longitude'] = longitudes

# Display the DataFrame with latitude and longitude columns
print(df.head())
# Out:
#     location_HQ                  Region       State      Country  \
# 0      Adelaide                     NaN         NaN    Australia
# 1  Agoura Hills                     NaN  California          USA
# 2     Ahmedabad                     NaN         NaN        India
# 3       Alameda  San Francisco Bay Area  California          USA
# 4     Amsterdam                     NaN         NaN  Netherlands
#
#        Continent   latitude   longitude
# 0         Oceana -34.928181  138.599931
# 1  North America  34.148169 -118.765546
# 2           Asia  23.021537   72.580057
# 3  North America  37.609029 -121.899142
# 4         Europe  52.373080    4.892453

# %%
display(df.head())
# Out:
#     location_HQ                  Region       State      Country  \
# 0      Adelaide                     NaN         NaN    Australia
# 1  Agoura Hills                     NaN  California          USA
# 2     Ahmedabad                     NaN         NaN        India
# 3       Alameda  San Francisco Bay Area  California          USA
# 4     Amsterdam                     NaN         NaN  Netherlands
#
#        Continent   latitude   longitude
# 0         Oceana -34.928181  138.599931
# 1  North America  34.148169 -118.765546
# 2           Asia  23.021537   72.580057
# 3  North America  37.609029 -121.899142
# 4         Europe  52.373080    4.892453

# %%
df.to_csv('layoffs_location_with_coordinates_new.csv', index=False)

# %%
# Assuming 'df' is your DataFrame containing latitude and longitude columns
df.to_csv('/Users/ulrike_imac_air/projects/DataScienceProjects/tech_layoffs/tech_layoffs_csv/layoffs_location_with_coordinates_new.csv', index=False)

display(df.head())
display(df.info(verbose=True))
# Out:
#     location_HQ                  Region       State      Country  \
# 0      Adelaide                     NaN         NaN    Australia
# 1  Agoura Hills                     NaN  California          USA
# 2     Ahmedabad                     NaN         NaN        India
# 3       Alameda  San Francisco Bay Area  California          USA
# 4     Amsterdam                     NaN         NaN  Netherlands
#
#        Continent   latitude   longitude
# 0         Oceana -34.928181  138.599931
# 1  North America  34.148169 -118.765546
# 2           Asia  23.021537   72.580057
# 3  North America  37.609029 -121.899142
# 4         Europe  52.373080    4.892453
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location_HQ  218 non-null    object
#  1   Region       35 non-null     object
#  2   State        116 non-null    object
#  3   Country      218 non-null    object
#  4   Continent    218 non-null    object
#  5   latitude     215 non-null    float64
#  6   longitude    215 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 12.1+ KB
# None

# %%
import folium
from branca.element import Figure

# Create a Figure object
fig = Figure(width=1024, height=600)

# Create a Folium Map object covering the whole world
fmap = folium.Map(location=[0, 0], tiles="openstreetmap", zoom_start=2)

# Filter out rows with NaN latitude or longitude
df_filtered = df.dropna(subset=['latitude', 'longitude'])

# Iterate over each row in the filtered DataFrame
for index, row in df_filtered.iterrows():
    latitude, longitude = row['latitude'], row['longitude']
    name = row["location_HQ"] 
    # Add marker to the map
    folium.Marker(location=[latitude, longitude], popup=name).add_to(fmap)

# Add the Folium Map object to the Figure
fig.add_child(fmap)

# Display the Figure
display(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72799f396b8181a3cd88b7f9e0c3355 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72799f396b8181a3cd88b7f9e0c3355&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72799f396b8181a3cd88b7f9e0c3355 = L.map(
#                 &quot;map_b72799f396b8181a3cd88b7f9e0c3355&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5cfb2e56105325747c7e1ecbb50d4d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5cfb2e56105325747c7e1ecbb50d4d8.addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#             var marker_bc8c5d827b4615d203dd0d9c6f0ad386 = L.marker(
#                 [-34.9281805, 138.5999312],
#                 {
# }
#             ).addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#         var popup_199e8658e13dbad170fbb62bde9b9a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60d3abb4e8d180bdf0a132aae7acf3ac = $(`&lt;div id=&quot;html_60d3abb4e8d180bdf0a132aae7acf3ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adelaide&lt;/div&gt;`)[0];
#                 popup_199e8658e13dbad170fbb62bde9b9a99.setContent(html_60d3abb4e8d180bdf0a132aae7acf3ac);
#
#
#
#         marker_bc8c5d827b4615d203dd0d9c6f0ad386.bindPopup(popup_199e8658e13dbad170fbb62bde9b9a99)
#         ;
#
#
#
#
#             var marker_188a6e3f5fcf78c7bdb86b3a69ad51e8 = L.marker(
#                 [34.1481692, -118.7655456],
#                 {
# }
#             ).addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#         var popup_d9020ae6f6aef35a470a8093771b6e54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c53a947438ffc75a56ada209fe2647c4 = $(`&lt;div id=&quot;html_c53a947438ffc75a56ada209fe2647c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agoura Hills&lt;/div&gt;`)[0];
#                 popup_d9020ae6f6aef35a470a8093771b6e54.setContent(html_c53a947438ffc75a56ada209fe2647c4);
#
#
#
#         marker_188a6e3f5fcf78c7bdb86b3a69ad51e8.bindPopup(popup_d9020ae6f6aef35a470a8093771b6e54)
#         ;
#
#
#
#
#             var marker_5c2cc7f62d5fd9aa26725262eba62603 = L.marker(
#                 [23.0215374, 72.5800568],
#                 {
# }
#             ).addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#         var popup_28581e130844e0bb01f17bc1e9838a72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72d31acd3eef3ee7ff872a0997bd8215 = $(`&lt;div id=&quot;html_72d31acd3eef3ee7ff872a0997bd8215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ahmedabad&lt;/div&gt;`)[0];
#                 popup_28581e130844e0bb01f17bc1e9838a72.setContent(html_72d31acd3eef3ee7ff872a0997bd8215);
#
#
#
#         marker_5c2cc7f62d5fd9aa26725262eba62603.bindPopup(popup_28581e130844e0bb01f17bc1e9838a72)
#         ;
#
#
#
#
#             var marker_381221acd3b7871a5f59f7b0e1117c30 = L.marker(
#                 [37.6090291, -121.899142],
#                 {
# }
#             ).addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#         var popup_88d56b542938b02e730b77d821a244cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91489c9843ed51a6afec968a18cf888a = $(`&lt;div id=&quot;html_91489c9843ed51a6afec968a18cf888a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alameda&lt;/div&gt;`)[0];
#                 popup_88d56b542938b02e730b77d821a244cf.setContent(html_91489c9843ed51a6afec968a18cf888a);
#
#
#
#         marker_381221acd3b7871a5f59f7b0e1117c30.bindPopup(popup_88d56b542938b02e730b77d821a244cf)
#         ;
#
#
#
#
#             var marker_1e6a09a79bdebf7e5a41019409fcbc68 = L.marker(
#                 [52.3730796, 4.8924534],
#                 {
# }
#             ).addTo(map_b72799f396b8181a3cd88b7f9e0c3355);
#
#
#         var popup_202e1c827d8a057eb993cb4c80e2b8ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b288b0594584a04199f96a446d9fa7d = $(`&lt;div id=&quot;html_9b288b0594584a04199f96a446d9fa7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amsterdam&lt;/div&gt;`)[0];
#                 popup_202e1c827d8a057eb993cb4c80e2b8ab.setContent(html_9b288b0594584a04199f96a446d9fa7d);
#
#
#
#         marker_1e6a09a79bdebf7e5a41019409fcbc68.bindPopup(popup_202e1c827d8a057eb993cb4c80e2b8ab)
#         ;
#
#
#
#
#             var marker_2ea7196e6020b4ad316c3a809ec84ff5 = L.marker(
#                 [42.2813722, -83

# %%
import folium
from branca.element import Figure

# Create a Figure object
fig = Figure(width=1024, height=600)

# Create a Folium Map object covering the whole world
fmap = folium.Map(location=[0, 0], tiles="openstreetmap", zoom_start=2)

# Filter out rows with NaN latitude or longitude
df_filtered = df.dropna(subset=['latitude', 'longitude'])

# Define the path to the custom icon
icon_path = '/Users/ulrike_imac_air/projects/DataScienceProjects/tech_layoffs/tech_layoffs_pictures/redsmallpin.png'  # Change this to the correct path to your icon file

# Iterate over each row in the filtered DataFrame
for index, row in df_filtered.iterrows():
    latitude, longitude = row['latitude'], row['longitude']
    name = row["location_HQ"] 
    
    # Create a custom icon
    icon = folium.CustomIcon(icon_image=icon_path, icon_size=(30, 30))  # Adjust icon_size as needed
    
    # Add marker to the map with the custom icon
    folium.Marker(location=[latitude, longitude], popup=name, icon=icon).add_to(fmap)

# Add the Folium Map object to the Figure
fig.add_child(fmap)

# Display the Figure
display(fig)
fig.show()
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99c252a5fd076183c2f2f992e3e07dd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99c252a5fd076183c2f2f992e3e07dd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99c252a5fd076183c2f2f992e3e07dd5 = L.map(
#                 &quot;map_99c252a5fd076183c2f2f992e3e07dd5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a848651e324d8070bdb4c64fb85efa2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a848651e324d8070bdb4c64fb85efa2.addTo(map_99c252a5fd076183c2f2f992e3e07dd5);
#
#
#             var marker_dda2d7dfe1634574291a856ae17d4bee = L.marker(
#                 [-34.9281805, 138.5999312],
#                 {
# }
#             ).addTo(map_99c252a5fd076183c2f2f992e3e07dd5);
#
#
#         var icon_dcf8995d1bf022ded92436a35c82c913 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#
#
#         var popup_4d0a8d5db26e82df4cef9335508531aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d64ad2a3c7399f4af158c95c86d34e = $(`&lt;div id=&quot;html_20d64ad2a3c7399f4af158c95c86d34e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adelaide&lt;/div&gt;`)[0];
#                 popup_4d0a8d5db26e82df4cef9335508531aa.setContent(html_20d64ad2a3c7399f4af158c95c86d34e);
#
#
#
#         marker_dda2d7dfe1634574291a856ae17d4bee.bindPopup(popup_4d0a8d5db26e82df4cef9335508531aa)
#         ;
#
#
#
#
#                 marker_dda2d7dfe1634574291a856ae17d4bee.setIcon(icon_dcf8995d1bf022ded92436a35c82c913);
#
#
#             var marker_f3b8daba21353ed0bade747624e8303a = L.marker(
#                 [34.1481692, -118.7655456],
#                 {
# }
#             ).addTo(map_99c252a5fd076183c2f2f992e3e07dd5);
#
#
#         var icon_0bc6171a83527f21bd14f66b09137e33 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#
#
#         var popup_704e1a917a07ae7f0ae0591c3c7398f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee89ffd56f17f932548efe0c004ad8d8 = $(`&lt;div id=&quot;html_ee89ffd56f17f932548efe0c004ad8d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agoura Hills&lt;/div&gt;`)[0];
#                 popup_704e1a917a07ae7f0ae0591c3c7398f5.setContent(html_ee89ffd56f17f932548efe0c004ad8d8);
#
#
#
#         marker_f3b8daba21353ed0bade747624e8303a.bindPopup(popup_704e1a917a07ae7f0ae0591c3c7398f5)
#         ;
#
#
#
#
#                 marker_f3b8daba21353ed0bade747624e8303a.setIcon(icon_0bc6171a83527f21bd14f66b09137e33);
#
#
#             var marker_64e095c6433f448849b3396ec9581735 = L.marker(
#                 [23.0215374, 72.5800568],
#                 {
# }
#             ).addTo(map_99c252a5fd076183c2f2f992e3e07dd5);
#
#
#         var icon_44846db11cdfe3c32128059280b10b2e = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#
#
#         var popup_40a4f9af632c132c4bf53502a7487277 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a64558470605c9ca7f294776ff0b90b5 = $(`&lt;div id=&quot;html_a64558470605c9ca7f294776ff0b90b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ahmedabad&lt;/div&gt;`)[0];
#                 popup_40a4f9af632c132c4bf53502a7487277.setContent(html_a64558470605c9ca7f294776ff0b90b5);
#
#
#
#         marker_64e095c6433f448849b3396ec9581735.bindPopup(popup_40a4f9af632c132c4bf53502a7487277)
#         ;
#
#
#
#
#                 marker_64e095c6433f448849b3396ec9581735.setIcon(icon_44846db11cdfe3c32128059280b10b2e);
#
#
#             var marker_5589a20180b3c1896acc66a607a4ce56 = L.marker(
#                 [37.6090291, -121.899142],
#                 {
# }
#             ).addTo(map_99c252a5fd076183c2f2f992e3e07dd5);
#
#
#         var icon_f7bbd24d84edd3c458f543c17caa9c48 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#
#
#         var popup_954a0586ba8ff22d0fddb3e2c2dff1a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a6d09344edc87b6586ad64d86850e26 = $(`&lt;div id=&quot;html_7a6d09344edc87b6586ad64d86850e26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alameda&lt;/div&gt;`)[0];
#                 popup_954a0586ba8ff22d0fddb3e2c2dff1a1.setContent(html_7a6d09344edc87b

# %%
gr_cat = df[["Country",
             "location_HQ"]].groupby(["Country",
                                       "location_HQ"], as_index=False).size()

# %%
import plotly.express as px

fig = px.sunburst(gr_cat, width=1280, height=800,
                  path=["Country","location_HQ"], values="size",
                  color="Country",
                  title="<span style='font-size:18px;'><b>Locations of tech layoffs by location HQ and countries (cities in total number)</b></span><b></b>"
                  )
fig.update_layout(font_size=10, margin=dict(l=10, r=10, t=30, b=50))
fig.update_traces(textinfo="label+percent parent")
fig.show()

# %%
fig = px.treemap(gr_cat, width=1280, height=800,
                 path=["Country","location_HQ"], values='size',
                 color='Country')
fig.update_traces(textinfo="label+percent parent")
fig.show()
